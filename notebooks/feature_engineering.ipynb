# %% [markdown]
# # Preprocessing and Feature engineering

# %%
import numpy as np
import pandas as pd

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# Reading csv
df = pd.read_csv('../data/Telco-Customer-Churn.csv')

# Dropping customer_id
df.drop(columns=['customerID'])

# %% [markdown]
# ##### Encoding

# %%
# Encdoing Churn 
df['Churn'] = (df['Churn'] == 'Yes').astype(int)

# Encoding Categoricals
df['Contract'] = pd.get_dummies( df, columns =  ['Contract', 'PaymentMethod', 'InternetService'], dtype=int )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       1 # Encdoing Churn
#       2 df['Churn'] = (df['Churn'] == 'Yes').astype(int)
#       3
#       4 # Encoding Categoricals
# ----> 5 df['Contract'] = pd.get_dummies( df['Contract'] )
#
# File c:\Users\syedm\Dev\Churn Prediction Pipeline\.venv\Lib\site-packages\pandas\core\frame.py:4662, in DataFrame.__setitem__(self, key, value)
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
# -> 4662             self._set_item_frame_value(key, value)
#    4663         elif (
#    4664             is_list_like(value)
#    4665             and not self.columns.is_unique
#
# File c:\Users\syedm\Dev\Churn Prediction Pipeline\.venv\Lib\site-packages\pandas\core\frame.py:4786, in DataFrame._set_item_frame_value(self, key, value)
#    4782             loc = self.columns.get_loc(key)
#    4783             cols = self.columns[loc]
#    4784             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4785             if len_cols != len(value.columns):
# -> 4786                 raise ValueError("Columns must be same length as key")
#    4787
#    4788             # align right-hand-side columns if self.columns
#    4789             # is multi-index and self[key] is a sub-frame
#
# ValueError: Columns must be same length as key
